# %% [markdown]
# # Ejercicio 5.6

# %%
import math
import matplotlib.pyplot as plt
from tabulate import tabulate 
# %matplotlib inline

raizReal=1.41906
result=0.7
xl, xu, xr=0.5, 2.0, 0.0
xl2, xu2, xr=0.5,2.0,0.0
cont=-2
evaluar, tabla1, aux1, aux2, tabla2, valores =[],[], [], [],[],[]
fA=1.0
fB=1.0
f1=1.0
f2=1.0
f3=1.0

while(cont<=2):
    x=math.pow(cont, 2)
    now=math.log(x)
    evaluar.append(now)
    valores.append(cont)
    tabla1.append([cont,now])
    cont+=0.02

def metodo1(value):
    arg=math.pow(value, 2)
    ln=math.log(arg)
    return ln
a=1   
while (a<4):
    xr=(xl+xu)/2
    aux1.append(xr)
    fA=metodo1(xl)
    fB=metodo1(xr)
    if ((fA*fB)<0):
        xu=xr
    if((fA*fB)>0):
         xl=xr
    a+=1
    
b=1  
while (b<4):
    f1=metodo1(xl2)
    f2=metodo1(xu2)
    xr2=xu2-(f2*(xl2-xu2))/(f1-f2)
    aux2.append(xr2)
    f3=metodo1(xr2)
    if ((f1*f3)<0):
        xu2=xr2
    if((f1*f3)>0):
         xl2=xr2 
    b+=1 

for i in range(0,3):
    tabla2.append([i+1,aux1[i], aux2[i]])

plt.title("Log")
plt.axis([0, 2, -2, 4])
plt.ylabel('ln(x^2)')
plt.xlabel('x')
plt.axhline(0, color="black")
plt.plot(valores, evaluar, 'b-', linewidth=2)
plt.plot(raizReal,0.7, 'co', label=' exacta=1.41907',linewidth=2)
plt.legend(loc = 'upper right', numpoints = 1)
plt.show()

print tabulate(tabla2, headers=["Iteracion","Biseccion","Falsa Posicion"], tablefmt="fancy_grid")
# Out:
# ╒═════════════╤═════════════╤══════════════════╕
# │   Iteracion │   Biseccion │   Falsa Posicion │
# ╞═════════════╪═════════════╪══════════════════╡
# │           1 │      1.25   │          1.25    │
# ├─────────────┼─────────────┼──────────────────┤
# │           2 │      0.875  │          1.06735 │
# ├─────────────┼─────────────┼──────────────────┤
# │           3 │      1.0625 │          1.01859 │
# ╘═════════════╧═════════════╧══════════════════╛
# ╒═════════════╤═════════════╤══════════════════╕
# │   Iteracion │   Biseccion │   Falsa Posicion │
# ╞═════════════╪═════════════╪══════════════════╡
# │           1 │      1.25   │          1.25    │
# ├─────────────┼─────────────┼──────────────────┤
# │           2 │      0.875  │          1.06735 │
# ├─────────────┼─────────────┼──────────────────┤
# │           3 │      1.0625 │          1.01859 │
# ╘═════════════╧═════════════╧══════════════════╛

# %% [markdown]
# # Ejercicio 5.7

# %%
import math
import matplotlib.pyplot as plt 
from tabulate import tabulate
# %matplotlib inline

x=-4
xl=1.0
xu=3.0
xr=0.0
valores, funcion, tabla, raices, tabla, aprox, tabla1=[],[],[],[],[],[],[]
i=0
true=2.69556

while(x<=4):
    if(x==0):
        continue
    else:
        fx=(0.8-0.3*x)/x
        valores.append(x)
        funcion.append(fx)
        x+=0.1
    tabla.append([valores[i], funcion[i]])
    i+=1

def metodo1(dato):
    fn=(0.8-0.3*dato)/dato
    return fn

b=0
while (b<3):
    f1=metodo1(xl)
    f2=metodo1(xu)
    xr=xu-(f2*(xl-xu))/(f1-f2)
    raices.append(xr)
    f3=metodo1(xr)
    erpv=math.fabs(((true-xr)/true)*100)
    if(b==0):
        aprox.append("-----")
        eaprx=100
    else:
        k=b-1
        eaprx=math.fabs(((raices[b]-raices[k])/raices[b])*100)
        aprox.append(eaprx)
    tabla1.append([b+1,xr, str(erpv)+" %", str(aprox[b])+" %"])
    if ((f1*f3)<0):
        xu=xr
    if((f1*f3)>0):
         xl=xr  
    b+=1
    
plt.title("f(x)")
plt.axis([-4, 5, -6, 6])
plt.ylabel('f(x)')
plt.xlabel('x')
plt.axhline(0, color="black")
plt.plot(valores, funcion, 'b-', linewidth=2)
plt.plot(true,0, 'co', label='Raiz Exacta=2.69556')
plt.legend(loc = 'upper right', numpoints = 1)
plt.show()

print "\nAnalitica:\n"
print tabulate(tabla, headers=["valor","funcion"], tablefmt="pipe")
print "\nUsando falsa posición iteracion 3\n"
print tabulate(tabla1, headers=["Iteracion","Raiz","Erpv","aprox"], tablefmt="pipe")
# Out:
# Analitica:
#
# |        valor |      funcion |
# |-------------:|-------------:|
# | -4           | -0.5         |
# | -3.9         | -0.505128    |
# | -3.8         | -0.510526    |
# | -3.7         | -0.516216    |
# | -3.6         | -0.522222    |
# | -3.5         | -0.528571    |
# | -3.4         | -0.535294    |
# | -3.3         | -0.542424    |
# | -3.2         | -0.55        |
# | -3.1         | -0.558065    |
# | -3           | -0.566667    |
# | -2.9         | -0.575862    |
# | -2.8         | -0.585714    |
# | -2.7         | -0.596296    |
# | -2.6         | -0.607692    |
# | -2.5         | -0.62        |
# | -2.4         | -0.633333    |
# | -2.3         | -0.647826    |
# | -2.2         | -0.663636    |
# | -2.1         | -0.680952    |
# | -2           | -0.7         |
# | -1.9         | -0.721053    |
# | -1.8         | -0.744444    |
# | -1.7         | -0.770588    |
# | -1.6         | -0.8         |
# | -1.5         | -0.833333    |
# ...
