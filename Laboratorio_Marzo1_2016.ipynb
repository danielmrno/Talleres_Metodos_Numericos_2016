# %% [markdown]
# # Biseccion

# %%
import math
import numpy as np
import pylab as pl
print "xl    xu    xr"
xl=1.0
xu=2.0
xr=0.0

def f(x):
    return (math.exp(-x))-x
def fxr(xl,xu):
    return (xl+xu)/2
print xl," ",xu," "," ",fxr(xl,xu)
if((f(xl)*f(xu))<0):
    xr=fxr(xl,xu)
aux=0
while((f(xl)*f(xr))!=0):
    if((f(xl)*f(xr))<0):
        xu=xr
        xr=fxr(xl,xu)
        print xl," ",xu," ",xr
        
    else:
        if((f(xl)*f(xr))>0):
            xl=xr
            xr=fxr(xl,xu)
            print xl," ",xu," ",xr
# Out:
#  xl    xu    xr
# 1.0   2.0     1.5
# 1.0   0.0   0.5
# 1.0   0.5   0.75
# 0.75   0.5   0.625
# 0.625   0.5   0.5625
# 0.625   0.5625   0.59375
# 0.59375   0.5625   0.578125
# 0.578125   0.5625   0.5703125
# 0.5703125   0.5625   0.56640625
# 0.5703125   0.56640625   0.568359375
# 0.568359375   0.56640625   0.5673828125
# 0.5673828125   0.56640625   0.56689453125
# 0.5673828125   0.56689453125   0.567138671875
# 0.5673828125   0.567138671875   0.567260742188
# 0.567260742188   0.567138671875   0.567199707031
# 0.567199707031   0.567138671875   0.567169189453
# 0.567169189453   0.567138671875   0.567153930664
# 0.567153930664   0.567138671875   0.56714630127
# 0.56714630127   0.567138671875   0.567142486572
# 0.56714630127   0.567142486572   0.567144393921
# 0.567144393921   0.567142486572   0.567143440247
# 0.567143440247   0.567142486572   0.567142963409
# 0.567143440247   0.567142963409   0.567143201828
# 0.567143440247   0.567143201828   0.567143321037
# ...

# %% [markdown]
# # falsa Posicion

# %%
import math
import numpy as np
import pylab as pl
print "xl    xu    xr"
xl=1.0
xu=2.0
xr=0.0
print xl," ",xu," ",fxr(xl,xu)
def f(x):
    return (math.exp(-x))-x
def fxr(xl,xu):
    return xu-((f(xu)*(xl-xu))/(f(xl)-f(xu)))
if((f(xl)*f(xu))<0):
    xr=fxr(xl,xu)
aux=0
while((f(xl)*f(xr))!=0):
    if((f(xl)*f(xr))<0):
        xu=xr
        xr=fxr(xl,xu)
        print xl," ",xu," ",xr
        
    else:
        if((f(xl)*f(xr))>0):
            xl=xr
            xr=fxr(xl,xu)
            print xl," ",xu," ",xr
# Out:
# xl    xu    xr
# 1.0   2.0   1.5
# 1.0   0.0   0.61269983678
# 0.61269983678   0.0   0.572181412091
# 0.572181412091   0.0   0.567703214236
# 0.567703214236   0.0   0.567205552633
# 0.567205552633   0.0   0.56715021424
# 0.56715021424   0.0   0.567144060375
# 0.567144060375   0.0   0.567143376034
# 0.567143376034   0.0   0.567143299932
# 0.567143299932   0.0   0.567143291469
# 0.567143291469   0.0   0.567143290528
# 0.567143290528   0.0   0.567143290423
# 0.567143290423   0.0   0.567143290411
# 0.567143290411   0.0   0.56714329041
# 0.56714329041   0.0   0.56714329041
# 0.56714329041   0.0   0.56714329041
# 0.56714329041   0.0   0.56714329041
# 0.56714329041   0.0   0.56714329041

# %% [markdown]
# # Punto Fijo

# %%
import math
def f(x):
    return (math.exp(-x))-x
def gx(x):
    return (math.exp(-x))
it=0
x=0
while(it<=10):
    print it, x
    x1=gx(x)
    x=gx(x)
    it+=1
